# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from keras.datasets import cifar10

# %%
def to_numpy(data_loader):
    images = []
    labels = []
    for inputs, targets in data_loader:
        images.append(inputs.numpy())
        labels.append(targets.numpy())
    images = np.vstack(images)
    labels = np.hstack(labels)
    return images, labels

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


train_images, train_labels = to_numpy(trainloader)
train_images = train_images.reshape(-1, 3072)
test_images, test_labels = to_numpy(testloader)
test_images = test_images.reshape(-1, 3072)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Neural Network without hyperparameter tuning

# %%
import numpy as np

class TwoLayerNN:
    def __init__(self, input_size, hidden_size, output_size):
        self.weights_input_hidden = np.random.randn(input_size, hidden_size) * 0.01
        self.biases_input_hidden = np.zeros((1, hidden_size))
        self.weights_hidden_output = np.random.randn(hidden_size, output_size) * 0.01
        self.biases_hidden_output = np.zeros((1, output_size))

    def custom_sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def custom_softmax(self, z):
        max_z = np.max(z, axis=1, keepdims=True)
        exp_z = np.exp(z - max_z)
        exp_sum = np.sum(exp_z, axis=1, keepdims=True)
        return exp_z / exp_sum

    def custom_forward_propagation(self, X):
        self.hidden_layer_input = np.dot(X, self.weights_input_hidden) + self.biases_input_hidden
        self.hidden_layer_activation = self.custom_sigmoid(self.hidden_layer_input)
        self.output_layer_input = np.dot(self.hidden_layer_activation, self.weights_hidden_output) + self.biases_hidden_output
        self.output_layer_activation = self.custom_softmax(self.output_layer_input)
        return self.output_layer_activation

    def custom_backward_propagation(self, X, Y, learning_rate):
        m = X.shape[0]

        # Calculating gradients for the output layer
        output_error = self.output_layer_activation - Y
        hidden_layer_output_transposed = self.hidden_layer_activation.T
        d_weights_hidden_output = np.dot(hidden_layer_output_transposed, output_error) / m
        d_biases_hidden_output = np.sum(output_error, axis=0, keepdims=True) / m

        # Calculating gradients for the hidden layer
        output_error_hidden = np.dot(output_error, self.weights_hidden_output.T)
        sigmoid_derivative = self.hidden_layer_activation * (1 - self.hidden_layer_activation)
        hidden_layer_error = output_error_hidden * sigmoid_derivative
        input_data_transposed = X.T
        d_weights_input_hidden = np.dot(input_data_transposed, hidden_layer_error) / m
        d_biases_input_hidden = np.sum(hidden_layer_error, axis=0, keepdims=True) / m

        # Updating weights and biases
        self.weights_hidden_output -= learning_rate * d_weights_hidden_output
        self.biases_hidden_output -= learning_rate * d_biases_hidden_output
        self.weights_input_hidden -= learning_rate * d_weights_input_hidden
        self.biases_input_hidden -= learning_rate * d_biases_input_hidden

# %%
# Example usage
input_size = 32 * 32 * 3
hidden_size = 128
output_size = 10
net = TwoLayerNN(input_size, hidden_size, output_size)

learning_rate = 0.01
epochs = 30

for epoch in range(epochs):
    # Forward pass
    train_output = net.custom_forward_propagation(train_images)

    # Compute loss
    m = train_images.shape[0]
    loss = -np.sum(np.eye(output_size)[train_labels] * np.log(train_output)) / m

    # Compute training accuracy
    train_predictions = np.argmax(train_output, axis=1)
    train_accuracy = np.mean(train_predictions == train_labels) * 100

    # Backward pass
    net.custom_backward_propagation(train_images, np.eye(output_size)[train_labels], learning_rate)

    print(f'Epoch {epoch+1}/{epochs}, Loss: {loss}, Training Accuracy: {train_accuracy:.2f}%')

# Test the network
test_output = net.custom_forward_propagation(test_images)
test_predictions = np.argmax(test_output, axis=1)
test_accuracy = np.mean(test_predictions == test_labels) * 100
print(f'Test Accuracy: {test_accuracy:.2f}%')
# Out:
# Epoch 1/30, Loss: 2.3030829168404936, Training Accuracy: 10.00%
# Epoch 2/30, Loss: 2.3029045864193063, Training Accuracy: 10.00%
# Epoch 3/30, Loss: 2.30273255223312, Training Accuracy: 10.00%
# Epoch 4/30, Loss: 2.3025663781042875, Training Accuracy: 10.00%
# Epoch 5/30, Loss: 2.3024056579999073, Training Accuracy: 10.00%
# Epoch 6/30, Loss: 2.302250013831455, Training Accuracy: 10.00%
# Epoch 7/30, Loss: 2.302099093426249, Training Accuracy: 10.00%
# Epoch 8/30, Loss: 2.3019525686560267, Training Accuracy: 10.00%
# Epoch 9/30, Loss: 2.3018101337092314, Training Accuracy: 10.00%
# Epoch 10/30, Loss: 2.301671503494984, Training Accuracy: 10.00%
# Epoch 11/30, Loss: 2.301536412167784, Training Accuracy: 10.00%
# Epoch 12/30, Loss: 2.3014046117630094, Training Accuracy: 10.00%
# Epoch 13/30, Loss: 2.3012758709342394, Training Accuracy: 10.00%
# Epoch 14/30, Loss: 2.3011499737841437, Training Accuracy: 10.00%
# Epoch 15/30, Loss: 2.3010267187815328, Training Accuracy: 10.00%
# Epoch 16/30, Loss: 2.3009059177577145, Training Accuracy: 10.00%
# Epoch 17/30, Loss: 2.3007873949759583, Training Accuracy: 10.00%
# Epoch 18/30, Loss: 2.300670986268391, Training Accuracy: 10.00%
# Epoch 19/30, Loss: 2.300556538235123, Training Accuracy: 10.00%
# Epoch 20/30, Loss: 2.300443907500831, Training Accuracy: 10.00%
# Epoch 21/30, Loss: 2.3003329600244635, Training Accuracy: 10.01%
# Epoch 22/30, Loss: 2.3002235704580256, Training Accuracy: 10.01%
# Epoch 23/30, Loss: 2.300115621550812, Training Accuracy: 10.02%
# Epoch 24/30, Loss: 2.300009003595662, Training Accuracy: 10.02%
# Epoch 25/30, Loss: 2.2999036139141635, Training Accuracy: 10.03%
# Epoch 26/30, Loss: 2.299799356377922, Training Accuracy: 10.04%
# Epoch 27/30, Loss: 2.299696140963267, Training Accuracy: 10.04%
# Epoch 28/30, Loss: 2.29959388333696, Training Accuracy: 10.05%
# Epoch 29/30, Loss: 2.2994925044706602, Training Accuracy: 10.07%
# Epoch 30/30, Loss: 2.2993919302820873, Training Accuracy: 10.12%
# Test Accuracy: 10.17%

# %% [markdown]
# ## Neural Network with L2 regularisation & Hyperparameter tuning

# %%
X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.20, random_state=42)

# %%
class CustomTwoLayerNNWithRegularisation:
    def __init__(self, input_size, hidden_size, output_size):
        self.weights_input_hidden = np.random.randn(input_size, hidden_size) * 0.01
        self.biases_input_hidden = np.zeros((1, hidden_size))
        self.weights_hidden_output = np.random.randn(hidden_size, output_size) * 0.01
        self.biases_hidden_output = np.zeros((1, output_size))

    def custom_sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def custom_softmax(self, z):
        max_z = np.max(z, axis=1, keepdims=True)
        exp_z = np.exp(z - max_z)
        exp_sum = np.sum(exp_z, axis=1, keepdims=True)
        return exp_z / exp_sum

    def custom_forward_propagation(self, X):
        self.hidden_layer_input = np.dot(X, self.weights_input_hidden) + self.biases_input_hidden
        self.hidden_layer_activation = self.custom_sigmoid(self.hidden_layer_input)
        self.output_layer_input = np.dot(self.hidden_layer_activation, self.weights_hidden_output) + self.biases_hidden_output
        self.output_layer_activation = self.custom_softmax(self.output_layer_input)
        return self.output_layer_activation

    def custom_backward_propagation_regularisation(self, X, Y, learning_rate, regularization_strength):
        m = X.shape[0]

        # Calculating gradients for the output layer
        output_error = self.output_layer_activation - Y
        hidden_layer_output_transposed = self.hidden_layer_activation.T
        d_weights_hidden_output = (np.dot(hidden_layer_output_transposed, output_error) + regularization_strength * self.weights_hidden_output) / m
        d_biases_hidden_output = np.sum(output_error, axis=0, keepdims=True) / m

        # Calculating gradients for the hidden layer
        output_error_hidden = np.dot(output_error, self.weights_hidden_output.T)
        sigmoid_derivative = self.hidden_layer_activation * (1 - self.hidden_layer_activation)
        hidden_layer_error = output_error_hidden * sigmoid_derivative
        input_data_transposed = X.T
        d_weights_input_hidden = (np.dot(input_data_transposed, hidden_layer_error) + regularization_strength * self.weights_input_hidden) / m
        d_biases_input_hidden = np.sum(hidden_layer_error, axis=0, keepdims=True) / m

        # Updating weights and biases
        self.weights_hidden_output -= learning_rate * d_weights_hidden_output
        self.biases_hidden_output -= learning_rate * d_biases_hidden_output
        self.weights_input_hidden -= learning_rate * d_weights_input_hidden
        self.biases_input_hidden -= learning_rate * d_biases_input_hidden

# %%
best_net = None
best_test_accuracy = 0
best_hyperparams = {'learning_rate': None, 'regularization_strength': None}
input_size = 32 * 32 * 3
hidden_size = 128
output_size = 10
learning_rates = [0.01, 0.1, 0.2, 0.3, 0.5]
regularization_strengths = [0.0000001, 0.000001, 0.00001]

epochs = 30
patience = 5  # Number of epochs to wait before early stopping

for lr in learning_rates:
    for reg_strength in regularization_strengths:
        print(f'Training with learning rate: {lr}, regularization strength: {reg_strength}')

        # Initialize the neural network
        net = CustomTwoLayerNNWithRegularisation(input_size, hidden_size, output_size)

        # Initialize variables for early stopping
        best_val_accuracy = 0
        epochs_without_improvement = 0

        # Train the network
        for epoch in range(epochs):
            # Forward pass
            train_output = net.custom_forward_propagation(X_train)

            # Compute loss
            loss = -np.sum(np.eye(output_size)[y_train] * np.log(train_output)) / X_train.shape[0]

            # Compute training accuracy
            train_predictions = np.argmax(train_output, axis=1)
            train_accuracy = np.mean(train_predictions == y_train) * 100
            print(f'Epoch {epoch+1}/{epochs}, Loss: {loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')

            # Backward pass with L2 regularization
            net.custom_backward_propagation_regularisation(X_train, np.eye(output_size)[y_train], lr, reg_strength)

            # Calculate validation accuracy
            val_output = net.custom_forward_propagation(X_val)
            val_predictions = np.argmax(val_output, axis=1)
            val_accuracy = np.mean(val_predictions == y_val) * 100
            print(f'Validation Accuracy: {val_accuracy:.2f}%')

            # Check for early stopping
            if val_accuracy > best_val_accuracy:
                best_val_accuracy = val_accuracy
                epochs_without_improvement = 0
            else:
                epochs_without_improvement += 1

            if epochs_without_improvement >= patience:
                print(f'Early stopping at epoch {epoch+1} due to no improvement in validation accuracy.')
                break

        # Calculate test accuracy after all epochs
        test_output = net.custom_forward_propagation(test_images)
        test_predictions = np.argmax(test_output, axis=1)
        test_accuracy = np.mean(test_predictions == test_labels) * 100
        print(f'Final Test Accuracy: {test_accuracy:.2f}%')

        # Update best hyperparameters and best model
        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_hyperparams['learning_rate'] = lr
            best_hyperparams['regularization_strength'] = reg_strength
            best_net = net

print(f'Best hyperparameters: Learning Rate = {best_hyperparams["learning_rate"]}, Regularization Strength = {best_hyperparams["regularization_strength"]}, Test Accuracy = {best_test_accuracy:.2f}%')
# Out:
# Training with learning rate: 0.01, regularization strength: 1e-07
# Epoch 1/30, Loss: 2.3057, Training Accuracy: 10.14%
# Validation Accuracy: 9.44%
# Epoch 2/30, Loss: 2.3054, Training Accuracy: 10.14%
# Validation Accuracy: 9.44%
# Epoch 3/30, Loss: 2.3051, Training Accuracy: 10.14%
# Validation Accuracy: 9.44%
# Epoch 4/30, Loss: 2.3049, Training Accuracy: 10.14%
# Validation Accuracy: 9.44%
# Epoch 5/30, Loss: 2.3046, Training Accuracy: 10.14%
# Validation Accuracy: 9.44%
# Epoch 6/30, Loss: 2.3044, Training Accuracy: 10.14%
# Validation Accuracy: 9.44%
# Early stopping at epoch 6 due to no improvement in validation accuracy.
# Final Test Accuracy: 10.00%
# Training with learning rate: 0.01, regularization strength: 1e-06
# Epoch 1/30, Loss: 2.3034, Training Accuracy: 10.03%
# Validation Accuracy: 9.86%
# Epoch 2/30, Loss: 2.3032, Training Accuracy: 10.03%
# Validation Accuracy: 9.86%
# Epoch 3/30, Loss: 2.3031, Training Accuracy: 10.04%
# Validation Accuracy: 9.86%
# Epoch 4/30, Loss: 2.3029, Training Accuracy: 10.03%
# Validation Accuracy: 9.86%
# Epoch 5/30, Loss: 2.3028, Training Accuracy: 10.03%
# Validation Accuracy: 9.86%
# Epoch 6/30, Loss: 2.3026, Training Accuracy: 10.03%
# Validation Accuracy: 9.87%
# Epoch 7/30, Loss: 2.3025, Training Accuracy: 10.03%
# Validation Accuracy: 9.87%
# Epoch 8/30, Loss: 2.3024, Training Accuracy: 10.03%
# Validation Accuracy: 9.88%
# Epoch 9/30, Loss: 2.3023, Training Accuracy: 10.02%
# Validation Accuracy: 9.89%
# Epoch 10/30, Loss: 2.3021, Training Accuracy: 10.04%
# Validation Accuracy: 9.89%
# Epoch 11/30, Loss: 2.3020, Training Accuracy: 10.03%
# Validation Accuracy: 9.88%
# Epoch 12/30, Loss: 2.3019, Training Accuracy: 10.05%
# Validation Accuracy: 9.89%
# Epoch 13/30, Loss: 2.3018, Training Accuracy: 10.04%
# Validation Accuracy: 9.94%
# Epoch 14/30, Loss: 2.3016, Training Accuracy: 10.04%
# Validation Accuracy: 9.96%
# Epoch 15/30, Loss: 2.3015, Training Accuracy: 10.04%
# Validation Accuracy: 9.97%
# Epoch 16/30, Loss: 2.3014, Training Accuracy: 10.06%
# Validation Accuracy: 9.99%
# Epoch 17/30, Loss: 2.3013, Training Accuracy: 10.08%
# Validation Accuracy: 9.99%
# Epoch 18/30, Loss: 2.3012, Training Accuracy: 10.11%
# Validation Accuracy: 10.00%
# Epoch 19/30, Loss: 2.3011, Training Accuracy: 10.11%
# Validation Accuracy: 10.02%
# Epoch 20/30, Loss: 2.3010, Training Accuracy: 10.13%
# Validation Accuracy: 10.00%
# Epoch 21/30, Loss: 2.3009, Training Accuracy: 10.15%
# Validation Accuracy: 10.04%
# Epoch 22/30, Loss: 2.3008, Training Accuracy: 10.16%
# Validation Accuracy: 10.05%
# Epoch 23/30, Loss: 2.3007, Training Accuracy: 10.17%
# Validation Accuracy: 10.01%
# Epoch 24/30, Loss: 2.3006, Training Accuracy: 10.20%
# Validation Accuracy: 10.01%
# Epoch 25/30, Loss: 2.3005, Training Accuracy: 10.21%
# Validation Accuracy: 10.05%
# Epoch 26/30, Loss: 2.3004, Training Accuracy: 10.26%
# Validation Accuracy: 10.08%
# Epoch 27/30, Loss: 2.3003, Training Accuracy: 10.27%
# Validation Accuracy: 10.06%
# Epoch 28/30, Loss: 2.3002, Training Accuracy: 10.31%
# Validation Accuracy: 10.13%
# Epoch 29/30, Loss: 2.3001, Training Accuracy: 10.40%
# Validation Accuracy: 10.20%
# Epoch 30/30, Loss: 2.3000, Training Accuracy: 10.47%
# Validation Accuracy: 10.28%
# Final Test Accuracy: 10.71%
# Training with learning rate: 0.01, regularization strength: 1e-05
# Epoch 1/30, Loss: 2.3060, Training Accuracy: 10.00%
# Validation Accuracy: 9.98%
# Epoch 2/30, Loss: 2.3058, Training Accuracy: 10.00%
# Validation Accuracy: 9.98%
# Epoch 3/30, Loss: 2.3055, Training Accuracy: 10.00%
# Validation Accuracy: 9.99%
# Epoch 4/30, Loss: 2.3053, Training Accuracy: 10.00%
# Validation Accuracy: 9.98%
# Epoch 5/30, Loss: 2.3051, Training Accuracy: 10.02%
# Validation Accuracy: 9.99%
# Epoch 6/30, Loss: 2.3049, Training Accuracy: 10.03%
# Validation Accuracy: 10.00%
# Epoch 7/30, Loss: 2.3047, Training Accuracy: 10.03%
# Validation Accuracy: 10.00%
# Epoch 8/30, Loss: 2.3045, Training Accuracy: 10.04%
# Validation Accuracy: 10.02%
# Epoch 9/30, Loss: 2.3044, Training Accuracy: 10.05%
# Validation Accuracy: 10.03%
# Epoch 10/30, Loss: 2.3042, Training Accuracy: 10.08%
# Validation Accuracy: 10.03%
# Epoch 11/30, Loss: 2.3040, Training Accuracy: 10.09%
# Validation Accuracy: 10.07%
# Epoch 12/30, Loss: 2.3039, Training Accuracy: 10.13%
# Validation Accuracy: 10.11%
# Epoch 13/30, Loss: 2.3037, Training Accuracy: 10.16%
# Validation Accuracy: 10.14%
# Epoch 14/30, Loss: 2.3036, Training Accuracy: 10.18%
# Validation Accuracy: 10.18%
# Epoch 15/30, Loss: 2.3034, Training Accuracy: 10.23%
# Validation Accuracy: 10.22%
# Epoch 16/30, Loss: 2.3033, Training Accuracy: 10.27%
# Validation Accuracy: 10.22%
# Epoch 17/30, Loss: 2.3031, Training Accuracy: 10.33%
# Validation Accuracy: 10.30%
# Epoch 18/30, Loss: 2.3030, Training Accuracy: 10.36%
# Validation Accuracy: 10.40%
# Epoch 19/30, Loss: 2.3029, Training Accuracy: 10.44%
# Validation Accuracy: 10.47%
# Epoch 20/30, Loss: 2.3028, Training Accuracy: 10.52%
# Validation Accuracy: 10.54%
# Epoch 21/30, Loss: 2.3026, Training Accuracy: 10.61%
# Validation Accuracy: 10.62%
# Epoch 22/30, Loss: 2.3025, Training Accuracy: 10.68%
# Validation Accuracy: 10.73%
# Epoch 23/30, Loss: 2.3024, Training Accuracy: 10.78%
# Validation Accuracy: 10.85%
# Epoch 24/30, Loss: 2.3023, Training Accuracy: 10.82%
# Validation Accuracy: 10.87%
# Epoch 25/30, Loss: 2.3022, Training Accuracy: 10.88%
# Validation Accuracy: 10.93%
# Epoch 26/30, Loss: 2.3021, Training Accuracy: 10.94%
# Validation Accuracy: 10.95%
# Epoch 27/30, Loss: 2.3020, Training Accuracy: 11.02%
# Validation Accuracy: 10.96%
# Epoch 28/30, Loss: 2.3019, Training Accuracy: 11.05%
# Validation Accuracy: 10.88%
# Epoch 29/30, Loss: 2.3018, Training Accuracy: 11.09%
# Validation Accuracy: 10.86%
# Epoch 30/30, Loss: 2.3017, Training Accuracy: 11.13%
# Validation Accuracy: 10.88%
# Final Test Accuracy: 11.00%
# Training with learning rate: 0.1, regularization strength: 1e-07
# Epoch 1/30, Loss: 2.3047, Training Accuracy: 9.76%
# Validation Accuracy: 9.51%
# Epoch 2/30, Loss: 2.3026, Training Accuracy: 9.80%
# Validation Accuracy: 9.60%
# Epoch 3/30, Loss: 2.3013, Training Accuracy: 9.86%
# Validation Accuracy: 9.75%
# Epoch 4/30, Loss: 2.3003, Training Accuracy: 10.09%
# Validation Accuracy: 11.44%
# Epoch 5/30, Loss: 2.2994, Training Accuracy: 11.64%
# Validation Accuracy: 13.06%
# Epoch 6/30, Loss: 2.2986, Training Accuracy: 13.71%
# Validation Accuracy: 14.64%
# Epoch 7/30, Loss: 2.2978, Training Accuracy: 14.92%
# Validation Accuracy: 15.58%
# Epoch 8/30, Loss: 2.2969, Training Accuracy: 16.12%
# Validation Accuracy: 16.65%
# Epoch 9/30, Loss: 2.2961, Training Accuracy: 17.22%
# Validation Accuracy: 17.91%
# Epoch 10/30, Loss: 2.2952, Training Accuracy: 18.45%
# Validation Accuracy: 18.86%
# Epoch 11/30, Loss: 2.2943, Training Accuracy: 19.35%
# Validation Accuracy: 19.82%
# Epoch 12/30, Loss: 2.2934, Training Accuracy: 20.21%
# Validation Accuracy: 20.46%
# Epoch 13/30, Loss: 2.2924, Training Accuracy: 20.93%
# Validation Accuracy: 21.04%
# Epoch 14/30, Loss: 2.2913, Training Accuracy: 21.50%
# Validation Accuracy: 21.54%
# Epoch 15/30, Loss: 2.2903, Training Accuracy: 21.98%
# Validation Accuracy: 21.74%
# Epoch 16/30, Loss: 2.2891, Training Accuracy: 22.52%
# Validation Accuracy: 22.25%
# Epoch 17/30, Loss: 2.2879, Training Accuracy: 22.83%
# Validation Accuracy: 22.47%
# Epoch 18/30, Loss: 2.2866, Training Accuracy: 23.25%
# Validation Accuracy: 22.96%
# Epoch 19/30, Loss: 2.2853, Training Accuracy: 23.57%
# Validation Accuracy: 23.23%
# Epoch 20/30, Loss: 2.2839, Training Accuracy: 23.83%
# Validation Accuracy: 23.38%
# Epoch 21/30, Loss: 2.2824, Training Accuracy: 24.07%
# Validation Accuracy: 23.52%
# Epoch 22/30, Loss: 2.2809, Training Accuracy: 24.28%
# Validation Accuracy: 23.43%
# Epoch 23/30, Loss: 2.2793, Training Accuracy: 24.34%
# Validation Accuracy: 23.63%
# Epoch 24/30, Loss: 2.2775, Training Accuracy: 24.30%
# Validation Accuracy: 23.72%
# Epoch 25/30, Loss: 2.2757, Training Accuracy: 24.35%
# Validation Accuracy: 23.77%
# Epoch 26/30, Loss: 2.2739, Training Accuracy: 24.39%
# Validation Accuracy: 23.72%
# Epoch 27/30, Loss: 2.2719, Training Accuracy: 24.33%
# Validation Accuracy: 23.67%
# Epoch 28/30, Loss: 2.2698, Training Accuracy: 24.27%
# Validation Accuracy: 23.70%
# Epoch 29/30, Loss: 2.2676, Training Accuracy: 24.30%
# Validation Accuracy: 23.73%
# Epoch 30/30, Loss: 2.2654, Training Accuracy: 24.30%
# Validation Accuracy: 23.70%
# Early stopping at epoch 30 due to no improvement in validation accuracy.
# Final Test Accuracy: 24.97%
# Training with learning rate: 0.1, regularization strength: 1e-06
# Epoch 1/30, Loss: 2.3047, Training Accuracy: 10.96%
# Validation Accuracy: 10.98%
# Epoch 2/30, Loss: 2.3023, Training Accuracy: 11.42%
# Validation Accuracy: 11.48%
# Epoch 3/30, Loss: 2.3009, Training Accuracy: 11.95%
# Validation Accuracy: 12.07%
# Epoch 4/30, Loss: 2.2998, Training Accuracy: 12.54%
# Validation Accuracy: 13.72%
# Epoch 5/30, Loss: 2.2989, Training Accuracy: 13.83%
# Validation Accuracy: 15.14%
# Epoch 6/30, Loss: 2.2981, Training Accuracy: 15.74%
# Validation Accuracy: 16.65%
# Epoch 7/30, Loss: 2.2972, Training Accuracy: 17.41%
# Validation Accuracy: 16.96%
# Epoch 8/30, Loss: 2.2964, Training Accuracy: 18.05%
# Validation Accuracy: 17.52%
# Epoch 9/30, Loss: 2.2955, Training Accuracy: 18.55%
# Validation Accuracy: 18.16%
# Epoch 10/30, Loss: 2.2946, Training Accuracy: 18.99%
# Validation Accuracy: 18.59%
# Epoch 11/30, Loss: 2.2937, Training Accuracy: 19.35%
# Validation Accuracy: 19.09%
# Epoch 12/30, Loss: 2.2927, Training Accuracy: 19.94%
# Validation Accuracy: 19.71%
# Epoch 13/30, Loss: 2.2916, Training Accuracy: 20.57%
# Validation Accuracy: 20.23%
# Epoch 14/30, Loss: 2.2905, Training Accuracy: 21.14%
# Validation Accuracy: 20.83%
# Epoch 15/30, Loss: 2.2894, Training Accuracy: 21.69%
# Validation Accuracy: 21.16%
# Epoch 16/30, Loss: 2.2881, Training Accuracy: 22.20%
# Validation Accuracy: 21.83%
# Epoch 17/30, Loss: 2.2869, Training Accuracy: 22.71%
# Validation Accuracy: 22.32%
# Epoch 18/30, Loss: 2.2855, Training Accuracy: 23.15%
# Validation Accuracy: 22.71%
# Epoch 19/30, Loss: 2.2841, Training Accuracy: 23.57%
# Validation Accuracy: 23.12%
# Epoch 20/30, Loss: 2.2825, Training Accuracy: 23.88%
# Validation Accuracy: 23.54%
# Epoch 21/30, Loss: 2.2809, Training Accuracy: 24.05%
# Validation Accuracy: 23.94%
# Epoch 22/30, Loss: 2.2792, Training Accuracy: 24.23%
# Validation Accuracy: 24.14%
# Epoch 23/30, Loss: 2.2774, Training Accuracy: 24.43%
# Validation Accuracy: 24.35%
# Epoch 24/30, Loss: 2.2756, Training Accuracy: 24.59%
# Validation Accuracy: 24.45%
# Epoch 25/30, Loss: 2.2736, Training Accuracy: 24.75%
# Validation Accuracy: 24.63%
# Epoch 26/30, Loss: 2.2715, Training Accuracy: 24.85%
# Validation Accuracy: 24.71%
# Epoch 27/30, Loss: 2.2693, Training Accuracy: 24.94%
# Validation Accuracy: 24.75%
# Epoch 28/30, Loss: 2.2671, Training Accuracy: 25.00%
# Validation Accuracy: 24.72%
# Epoch 29/30, Loss: 2.2647, Training Accuracy: 24.99%
# Validation Accuracy: 24.76%
# Epoch 30/30, Loss: 2.2622, Training Accuracy: 24.98%
# Validation Accuracy: 24.75%
# Final Test Accuracy: 25.11%
# Training with learning rate: 0.1, regularization strength: 1e-05
# Epoch 1/30, Loss: 2.3048, Training Accuracy: 8.45%
# Validation Accuracy: 9.24%
# Epoch 2/30, Loss: 2.3030, Training Accuracy: 9.45%
# Validation Accuracy: 10.27%
# Epoch 3/30, Loss: 2.3017, Training Accuracy: 10.47%
# Validation Accuracy: 11.29%
# Epoch 4/30, Loss: 2.3008, Training Accuracy: 11.72%
# Validation Accuracy: 13.13%
# Epoch 5/30, Loss: 2.2999, Training Accuracy: 13.76%
# Validation Accuracy: 14.86%
# Epoch 6/30, Loss: 2.2990, Training Accuracy: 15.42%
# Validation Accuracy: 16.31%
# Epoch 7/30, Loss: 2.2982, Training Accuracy: 17.03%
# Validation Accuracy: 17.88%
# Epoch 8/30, Loss: 2.2974, Training Accuracy: 18.64%
# Validation Accuracy: 19.37%
# Epoch 9/30, Loss: 2.2965, Training Accuracy: 19.93%
# Validation Accuracy: 20.29%
# Epoch 10/30, Loss: 2.2956, Training Accuracy: 20.97%
# Validation Accuracy: 21.01%
# Epoch 11/30, Loss: 2.2947, Training Accuracy: 21.54%
# Validation Accuracy: 21.40%
# Epoch 12/30, Loss: 2.2937, Training Accuracy: 22.03%
# Validation Accuracy: 21.82%
# Epoch 13/30, Loss: 2.2927, Training Accuracy: 22.43%
# Validation Accuracy: 22.02%
# Epoch 14/30, Loss: 2.2917, Training Accuracy: 22.72%
# Validation Accuracy: 22.36%
# Epoch 15/30, Loss: 2.2906, Training Accuracy: 22.92%
# Validation Accuracy: 22.56%
# Epoch 16/30, Loss: 2.2894, Training Accuracy: 23.04%
# Validation Accuracy: 22.58%
# Epoch 17/30, Loss: 2.2882, Training Accuracy: 23.16%
# Validation Accuracy: 22.59%
# Epoch 18/30, Loss: 2.2869, Training Accuracy: 23.32%
# Validation Accuracy: 22.69%
# Epoch 19/30, Loss: 2.2855, Training Accuracy: 23.30%
# Validation Accuracy: 22.72%
# Epoch 20/30, Loss: 2.2841, Training Accuracy: 23.32%
# Validation Accuracy: 22.77%
# Epoch 21/30, Loss: 2.2826, Training Accuracy: 23.28%
# Validation Accuracy: 22.68%
# Epoch 22/30, Loss: 2.2810, Training Accuracy: 23.33%
# Validation Accuracy: 22.62%
# Epoch 23/30, Loss: 2.2793, Training Accuracy: 23.29%
# Validation Accuracy: 22.65%
# Epoch 24/30, Loss: 2.2775, Training Accuracy: 23.24%
# Validation Accuracy: 22.68%
# Epoch 25/30, Loss: 2.2757, Training Accuracy: 23.14%
# Validation Accuracy: 22.52%
# Early stopping at epoch 25 due to no improvement in validation accuracy.
# Final Test Accuracy: 23.32%
# Training with learning rate: 0.2, regularization strength: 1e-07
# Epoch 1/30, Loss: 2.3041, Training Accuracy: 10.01%
# Validation Accuracy: 10.11%
# Epoch 2/30, Loss: 2.3004, Training Accuracy: 10.26%
# Validation Accuracy: 15.51%
# Epoch 3/30, Loss: 2.2984, Training Accuracy: 16.42%
# Validation Accuracy: 16.57%
# Epoch 4/30, Loss: 2.2966, Training Accuracy: 17.39%
# Validation Accuracy: 17.74%
# Epoch 5/30, Loss: 2.2946, Training Accuracy: 18.62%
# Validation Accuracy: 19.03%
# Epoch 6/30, Loss: 2.2925, Training Accuracy: 19.89%
# Validation Accuracy: 19.83%
# Epoch 7/30, Loss: 2.2902, Training Accuracy: 21.04%
# Validation Accuracy: 20.66%
# Epoch 8/30, Loss: 2.2876, Training Accuracy: 21.85%
# Validation Accuracy: 21.37%
# Epoch 9/30, Loss: 2.2848, Training Accuracy: 22.48%
# Validation Accuracy: 22.01%
# Epoch 10/30, Loss: 2.2817, Training Accuracy: 23.00%
# Validation Accuracy: 22.55%
# Epoch 11/30, Loss: 2.2783, Training Accuracy: 23.38%
# Validation Accuracy: 22.93%
# Epoch 12/30, Loss: 2.2746, Training Accuracy: 23.59%
# Validation Accuracy: 23.16%
# Epoch 13/30, Loss: 2.2705, Training Accuracy: 23.75%
# Validation Accuracy: 23.19%
# Epoch 14/30, Loss: 2.2660, Training Accuracy: 23.79%
# Validation Accuracy: 23.13%
# Epoch 15/30, Loss: 2.2611, Training Accuracy: 23.88%
# Validation Accuracy: 23.30%
# Epoch 16/30, Loss: 2.2559, Training Accuracy: 23.93%
# Validation Accuracy: 23.31%
# Epoch 17/30, Loss: 2.2504, Training Accuracy: 23.86%
# Validation Accuracy: 23.14%
# Epoch 18/30, Loss: 2.2446, Training Accuracy: 23.84%
# Validation Accuracy: 23.21%
# Epoch 19/30, Loss: 2.2386, Training Accuracy: 23.80%
# Validation Accuracy: 23.31%
# Epoch 20/30, Loss: 2.2323, Training Accuracy: 23.84%
# Validation Accuracy: 23.33%
# Epoch 21/30, Loss: 2.2260, Training Accuracy: 23.86%
# Validation Accuracy: 23.32%
# Epoch 22/30, Loss: 2.2196, Training Accuracy: 23.89%
# Validation Accuracy: 23.40%
# Epoch 23/30, Loss: 2.2131, Training Accuracy: 23.91%
# Validation Accuracy: 23.47%
# Epoch 24/30, Loss: 2.2067, Training Accuracy: 23.99%
# Validation Accuracy: 23.61%
# Epoch 25/30, Loss: 2.2003, Training Accuracy: 24.02%
# Validation Accuracy: 23.76%
# Epoch 26/30, Loss: 2.1941, Training Accuracy: 24.12%
# Validation Accuracy: 23.87%
# Epoch 27/30, Loss: 2.1879, Training Accuracy: 24.19%
# Validation Accuracy: 23.97%
# Epoch 28/30, Loss: 2.1819, Training Accuracy: 24.27%
# Validation Accuracy: 24.11%
# Epoch 29/30, Loss: 2.1761, Training Accuracy: 24.39%
# Validation Accuracy: 24.30%
# Epoch 30/30, Loss: 2.1703, Training Accuracy: 24.47%
# Validation Accuracy: 24.49%
# Final Test Accuracy: 25.04%
# Training with learning rate: 0.2, regularization strength: 1e-06
# Epoch 1/30, Loss: 2.3037, Training Accuracy: 10.24%
# Validation Accuracy: 11.80%
# Epoch 2/30, Loss: 2.3007, Training Accuracy: 11.67%
# Validation Accuracy: 14.83%
# Epoch 3/30, Loss: 2.2990, Training Accuracy: 14.67%
# Validation Accuracy: 17.15%
# Epoch 4/30, Loss: 2.2973, Training Accuracy: 17.81%
# Validation Accuracy: 18.33%
# Epoch 5/30, Loss: 2.2955, Training Accuracy: 18.62%
# Validation Accuracy: 19.38%
# Epoch 6/30, Loss: 2.2936, Training Accuracy: 19.24%
# Validation Accuracy: 19.83%
# Epoch 7/30, Loss: 2.2916, Training Accuracy: 19.88%
# Validation Accuracy: 20.23%
# Epoch 8/30, Loss: 2.2893, Training Accuracy: 20.38%
# Validation Accuracy: 20.55%
# Epoch 9/30, Loss: 2.2869, Training Accuracy: 20.72%
# Validation Accuracy: 20.57%
# Epoch 10/30, Loss: 2.2841, Training Accuracy: 21.02%
# Validation Accuracy: 20.80%
# Epoch 11/30, Loss: 2.2811, Training Accuracy: 21.28%
# Validation Accuracy: 20.98%
# Epoch 12/30, Loss: 2.2777, Training Accuracy: 21.49%
# Validation Accuracy: 21.26%
# Epoch 13/30, Loss: 2.2740, Training Accuracy: 21.70%
# Validation Accuracy: 21.46%
# Epoch 14/30, Loss: 2.2699, Training Accuracy: 21.77%
# Validation Accuracy: 21.83%
# Epoch 15/30, Loss: 2.2655, Training Accuracy: 21.95%
# Validation Accuracy: 21.80%
# Epoch 16/30, Loss: 2.2607, Training Accuracy: 21.98%
# Validation Accuracy: 21.81%
# Epoch 17/30, Loss: 2.2556, Training Accuracy: 22.03%
# Validation Accuracy: 21.79%
# Epoch 18/30, Loss: 2.2502, Training Accuracy: 22.16%
# Validation Accuracy: 21.67%
# Epoch 19/30, Loss: 2.2445, Training Accuracy: 22.19%
# Validation Accuracy: 21.81%
# Early stopping at epoch 19 due to no improvement in validation accuracy.
# Final Test Accuracy: 22.44%
# Training with learning rate: 0.2, regularization strength: 1e-05
# Epoch 1/30, Loss: 2.3040, Training Accuracy: 9.14%
# Validation Accuracy: 12.90%
# Epoch 2/30, Loss: 2.3006, Training Accuracy: 13.55%
# Validation Accuracy: 14.36%
# Epoch 3/30, Loss: 2.2988, Training Accuracy: 15.12%
# Validation Accuracy: 15.54%
# Epoch 4/30, Loss: 2.2970, Training Accuracy: 16.10%
# Validation Accuracy: 17.10%
# Epoch 5/30, Loss: 2.2953, Training Accuracy: 17.52%
# Validation Accuracy: 18.51%
# Epoch 6/30, Loss: 2.2934, Training Accuracy: 19.09%
# Validation Accuracy: 19.74%
# Epoch 7/30, Loss: 2.2913, Training Accuracy: 20.34%
# Validation Accuracy: 20.70%
# Epoch 8/30, Loss: 2.2891, Training Accuracy: 21.20%
# Validation Accuracy: 21.44%
# Epoch 9/30, Loss: 2.2866, Training Accuracy: 21.93%
# Validation Accuracy: 22.19%
# Epoch 10/30, Loss: 2.2838, Training Accuracy: 22.48%
# Validation Accuracy: 22.31%
# Epoch 11/30, Loss: 2.2808, Training Accuracy: 22.80%
# Validation Accuracy: 22.66%
# Epoch 12/30, Loss: 2.2774, Training Accuracy: 22.98%
# Validation Accuracy: 22.57%
# Epoch 13/30, Loss: 2.2737, Training Accuracy: 23.04%
# Validation Accuracy: 22.43%
# Epoch 14/30, Loss: 2.2697, Training Accuracy: 23.02%
# Validation Accuracy: 22.62%
# Epoch 15/30, Loss: 2.2653, Training Accuracy: 22.96%
# Validation Accuracy: 22.55%
# Epoch 16/30, Loss: 2.2605, Training Accuracy: 22.93%
# Validation Accuracy: 22.58%
# Early stopping at epoch 16 due to no improvement in validation accuracy.
# Final Test Accuracy: 23.21%
# Training with learning rate: 0.3, regularization strength: 1e-07
# Epoch 1/30, Loss: 2.3043, Training Accuracy: 10.35%
# Validation Accuracy: 13.36%
# Epoch 2/30, Loss: 2.3007, Training Accuracy: 13.73%
# Validation Accuracy: 14.78%
# Epoch 3/30, Loss: 2.2984, Training Accuracy: 15.30%
# Validation Accuracy: 16.92%
# Epoch 4/30, Loss: 2.2960, Training Accuracy: 17.38%
# Validation Accuracy: 18.71%
# Epoch 5/30, Loss: 2.2933, Training Accuracy: 19.17%
# Validation Accuracy: 20.06%
# Epoch 6/30, Loss: 2.2902, Training Accuracy: 20.74%
# Validation Accuracy: 21.58%
# Epoch 7/30, Loss: 2.2867, Training Accuracy: 22.25%
# Validation Accuracy: 22.68%
# Epoch 8/30, Loss: 2.2825, Training Accuracy: 23.32%
# Validation Accuracy: 23.14%
# Epoch 9/30, Loss: 2.2777, Training Accuracy: 23.83%
# Validation Accuracy: 23.41%
# Epoch 10/30, Loss: 2.2722, Training Accuracy: 23.99%
# Validation Accuracy: 23.67%
# Epoch 11/30, Loss: 2.2658, Training Accuracy: 23.98%
# Validation Accuracy: 23.58%
# Epoch 12/30, Loss: 2.2587, Training Accuracy: 23.95%
# Validation Accuracy: 23.40%
# Epoch 13/30, Loss: 2.2507, Training Accuracy: 23.95%
# Validation Accuracy: 23.40%
# Epoch 14/30, Loss: 2.2422, Training Accuracy: 23.97%
# Validation Accuracy: 23.44%
# Epoch 15/30, Loss: 2.2331, Training Accuracy: 23.89%
# Validation Accuracy: 23.43%
# Early stopping at epoch 15 due to no improvement in validation accuracy.
# Final Test Accuracy: 24.20%
# Training with learning rate: 0.3, regularization strength: 1e-06
# Epoch 1/30, Loss: 2.3045, Training Accuracy: 10.91%
# Validation Accuracy: 10.75%
# Epoch 2/30, Loss: 2.3007, Training Accuracy: 11.18%
# Validation Accuracy: 14.52%
# Epoch 3/30, Loss: 2.2986, Training Accuracy: 14.39%
# Validation Accuracy: 17.72%
# Epoch 4/30, Loss: 2.2963, Training Accuracy: 17.75%
# Validation Accuracy: 19.62%
# Epoch 5/30, Loss: 2.2938, Training Accuracy: 19.81%
# Validation Accuracy: 21.20%
# Epoch 6/30, Loss: 2.2910, Training Accuracy: 21.16%
# Validation Accuracy: 22.03%
# Epoch 7/30, Loss: 2.2877, Training Accuracy: 22.32%
# Validation Accuracy: 22.62%
# Epoch 8/30, Loss: 2.2838, Training Accuracy: 23.16%
# Validation Accuracy: 23.21%
# Epoch 9/30, Loss: 2.2792, Training Accuracy: 23.67%
# Validation Accuracy: 23.55%
# Epoch 10/30, Loss: 2.2739, Training Accuracy: 23.94%
# Validation Accuracy: 23.35%
# Epoch 11/30, Loss: 2.2678, Training Accuracy: 24.03%
# Validation Accuracy: 23.32%
# Epoch 12/30, Loss: 2.2609, Training Accuracy: 23.97%
# Validation Accuracy: 23.18%
# Epoch 13/30, Loss: 2.2532, Training Accuracy: 23.81%
# Validation Accuracy: 23.10%
# Epoch 14/30, Loss: 2.2449, Training Accuracy: 23.53%
# Validation Accuracy: 22.94%
# Early stopping at epoch 14 due to no improvement in validation accuracy.
# Final Test Accuracy: 23.99%
# Training with learning rate: 0.3, regularization strength: 1e-05
# Epoch 1/30, Loss: 2.3045, Training Accuracy: 9.94%
# Validation Accuracy: 12.48%
# Epoch 2/30, Loss: 2.2998, Training Accuracy: 13.26%
# Validation Accuracy: 16.26%
# Epoch 3/30, Loss: 2.2972, Training Accuracy: 17.10%
# Validation Accuracy: 18.82%
# Epoch 4/30, Loss: 2.2944, Training Accuracy: 19.66%
# Validation Accuracy: 20.83%
# Epoch 5/30, Loss: 2.2913, Training Accuracy: 21.65%
# Validation Accuracy: 22.47%
# Epoch 6/30, Loss: 2.2877, Training Accuracy: 22.89%
# Validation Accuracy: 23.22%
# Epoch 7/30, Loss: 2.2836, Training Accuracy: 23.61%
# Validation Accuracy: 23.73%
# Epoch 8/30, Loss: 2.2789, Training Accuracy: 24.17%
# Validation Accuracy: 23.91%
# Epoch 9/30, Loss: 2.2735, Training Accuracy: 24.30%
# Validation Accuracy: 23.92%
# Epoch 10/30, Loss: 2.2672, Training Accuracy: 24.22%
# Validation Accuracy: 23.62%
# Epoch 11/30, Loss: 2.2602, Training Accuracy: 24.11%
# Validation Accuracy: 23.36%
# Epoch 12/30, Loss: 2.2524, Training Accuracy: 24.00%
# Validation Accuracy: 23.18%
# Epoch 13/30, Loss: 2.2440, Training Accuracy: 23.95%
# Validation Accuracy: 23.21%
# Epoch 14/30, Loss: 2.2349, Training Accuracy: 23.84%
# Validation Accuracy: 23.27%
# Early stopping at epoch 14 due to no improvement in validation accuracy.
# Final Test Accuracy: 24.27%
# Training with learning rate: 0.5, regularization strength: 1e-07
# Epoch 1/30, Loss: 2.3044, Training Accuracy: 10.09%
# Validation Accuracy: 11.36%
# Epoch 2/30, Loss: 2.2991, Training Accuracy: 11.07%
# Validation Accuracy: 9.64%
# Epoch 3/30, Loss: 2.2940, Training Accuracy: 10.10%
# Validation Accuracy: 22.05%
# Epoch 4/30, Loss: 2.2888, Training Accuracy: 22.32%
# Validation Accuracy: 19.84%
# Epoch 5/30, Loss: 2.2823, Training Accuracy: 20.40%
# Validation Accuracy: 22.91%
# Epoch 6/30, Loss: 2.2743, Training Accuracy: 23.10%
# Validation Accuracy: 23.67%
# Epoch 7/30, Loss: 2.2644, Training Accuracy: 24.00%
# Validation Accuracy: 22.93%
# Epoch 8/30, Loss: 2.2523, Training Accuracy: 23.35%
# Validation Accuracy: 23.24%
# Epoch 9/30, Loss: 2.2385, Training Accuracy: 23.72%
# Validation Accuracy: 23.11%
# Epoch 10/30, Loss: 2.2234, Training Accuracy: 23.50%
# Validation Accuracy: 23.30%
# Epoch 11/30, Loss: 2.2078, Training Accuracy: 23.72%
# Validation Accuracy: 23.64%
# Early stopping at epoch 11 due to no improvement in validation accuracy.
# Final Test Accuracy: 24.51%
# Training with learning rate: 0.5, regularization strength: 1e-06
# Epoch 1/30, Loss: 2.3020, Training Accuracy: 10.11%
# Validation Accuracy: 13.69%
# Epoch 2/30, Loss: 2.2975, Training Accuracy: 14.16%
# Validation Accuracy: 18.53%
# Epoch 3/30, Loss: 2.2929, Training Accuracy: 18.99%
# Validation Accuracy: 22.82%
# Epoch 4/30, Loss: 2.2875, Training Accuracy: 23.43%
# Validation Accuracy: 22.83%
# Epoch 5/30, Loss: 2.2807, Training Accuracy: 23.32%
# Validation Accuracy: 24.70%
# Epoch 6/30, Loss: 2.2720, Training Accuracy: 25.29%
# Validation Accuracy: 24.35%
# Epoch 7/30, Loss: 2.2612, Training Accuracy: 24.71%
# Validation Accuracy: 24.27%
# Epoch 8/30, Loss: 2.2482, Training Accuracy: 24.76%
# Validation Accuracy: 23.97%
# Epoch 9/30, Loss: 2.2334, Training Accuracy: 24.42%
# Validation Accuracy: 23.84%
# Epoch 10/30, Loss: 2.2173, Training Accuracy: 24.29%
# Validation Accuracy: 23.79%
# Early stopping at epoch 10 due to no improvement in validation accuracy.
# Final Test Accuracy: 24.94%
# Training with learning rate: 0.5, regularization strength: 1e-05
# Epoch 1/30, Loss: 2.3069, Training Accuracy: 9.97%
# Validation Accuracy: 9.84%
# Epoch 2/30, Loss: 2.3007, Training Accuracy: 10.05%
# Validation Accuracy: 15.87%
# Epoch 3/30, Loss: 2.2959, Training Accuracy: 15.95%
# Validation Accuracy: 13.64%
# Epoch 4/30, Loss: 2.2908, Training Accuracy: 14.17%
# Validation Accuracy: 21.43%
# Epoch 5/30, Loss: 2.2847, Training Accuracy: 21.73%
# Validation Accuracy: 22.22%
# Epoch 6/30, Loss: 2.2770, Training Accuracy: 22.31%
# Validation Accuracy: 22.54%
# Epoch 7/30, Loss: 2.2673, Training Accuracy: 22.83%
# Validation Accuracy: 22.95%
# Epoch 8/30, Loss: 2.2553, Training Accuracy: 23.29%
# Validation Accuracy: 22.39%
# Epoch 9/30, Loss: 2.2414, Training Accuracy: 22.71%
# Validation Accuracy: 22.67%
# Epoch 10/30, Loss: 2.2260, Training Accuracy: 22.99%
# Validation Accuracy: 22.63%
# Epoch 11/30, Loss: 2.2101, Training Accuracy: 23.00%
# Validation Accuracy: 22.98%
# Epoch 12/30, Loss: 2.1944, Training Accuracy: 23.37%
# Validation Accuracy: 23.31%
# Epoch 13/30, Loss: 2.1794, Training Accuracy: 23.57%
# Validation Accuracy: 23.67%
# Epoch 14/30, Loss: 2.1653, Training Accuracy: 23.99%
# Validation Accuracy: 24.05%
# Epoch 15/30, Loss: 2.1521, Training Accuracy: 24.36%
# Validation Accuracy: 24.48%
# Epoch 16/30, Loss: 2.1395, Training Accuracy: 24.79%
# Validation Accuracy: 24.95%
# Epoch 17/30, Loss: 2.1275, Training Accuracy: 25.14%
# Validation Accuracy: 25.42%
# Epoch 18/30, Loss: 2.1159, Training Accuracy: 25.49%
# Validation Accuracy: 25.57%
# Epoch 19/30, Loss: 2.1047, Training Accuracy: 25.92%
# Validation Accuracy: 25.88%
# Epoch 20/30, Loss: 2.0939, Training Accuracy: 26.36%
# Validation Accuracy: 26.28%
# Epoch 21/30, Loss: 2.0836, Training Accuracy: 26.72%
# Validation Accuracy: 26.44%
# Epoch 22/30, Loss: 2.0737, Training Accuracy: 26.93%
# Validation Accuracy: 26.94%
# Epoch 23/30, Loss: 2.0643, Training Accuracy: 27.12%
# Validation Accuracy: 27.33%
# Epoch 24/30, Loss: 2.0553, Training Accuracy: 27.38%
# Validation Accuracy: 27.49%
# Epoch 25/30, Loss: 2.0468, Training Accuracy: 27.64%
# Validation Accuracy: 27.72%
# Epoch 26/30, Loss: 2.0387, Training Accuracy: 27.82%
# Validation Accuracy: 27.88%
# Epoch 27/30, Loss: 2.0310, Training Accuracy: 28.06%
# Validation Accuracy: 27.99%
# Epoch 28/30, Loss: 2.0238, Training Accuracy: 28.31%
# Validation Accuracy: 28.14%
# Epoch 29/30, Loss: 2.0169, Training Accuracy: 28.44%
# Validation Accuracy: 28.31%
# Epoch 30/30, Loss: 2.0103, Training Accuracy: 28.57%
# Validation Accuracy: 28.35%
# Final Test Accuracy: 29.13%
# Best hyperparameters: Learning Rate = 0.5, Regularization Strength = 1e-05, Test Accuracy = 29.13%
