# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %% [markdown]
# #### Data Loading and Preliminary Analysis

# %%
data = pd.read_csv('penguins.csv')

# %%
data.head(3)
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %% [markdown]
# #### Data Cleaning and PreProcessing

# %%
data.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
data['bill_length_mm'] = data['bill_length_mm'].fillna(data['bill_length_mm'].mean())
data['bill_depth_mm'] = data['bill_depth_mm'].fillna(data['bill_depth_mm'].mean())
data['flipper_length_mm'] = data['flipper_length_mm'].fillna(data['flipper_length_mm'].mean())
data['body_mass_g'] = data['body_mass_g'].fillna(data['body_mass_g'].mean())
data['sex'] = data['sex'].fillna(data['sex'].mode()[0])

# %%
data.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# ### EDA:

# %%
data.plot(y='bill_length_mm', kind = 'box')
plt.title('bill_length_mm distribution')
plt.show()

# %%
data.plot(y='bill_depth_mm', kind = 'box')
plt.title('bill_depth_mm distribution')
plt.show()

# %%
data.plot(y='flipper_length_mm', kind = 'box')
plt.title('flipper_length_mm distribution')
plt.show()

# %%
data.plot(y='body_mass_g', kind = 'box')
plt.title('body_mass_g distribution')
plt.show()

# %%
species = list(data['species'].unique())
counts = []
for specimen in species:
    counts.append(data[data['species']==specimen].shape[0])
    
plt.bar(species, counts)
plt.xlabel('Species')
plt.ylabel('frequency')
plt.title('Bar plot of Species')
# Out:
# Text(0.5, 1.0, 'Bar plot of Species')

# %%
islands = list(data['island'].unique())
counts = []
for island in islands:
    counts.append(data[data['island']==island].shape[0])
    
plt.bar(islands, counts)
plt.xlabel('Islands')
plt.ylabel('frequency')
plt.title('Bar plot of Islands')
# Out:
# Text(0.5, 1.0, 'Bar plot of Islands')

# %%
genders = list(data['sex'].unique())
counts = []
for gender in genders:
    counts.append(data[data['sex']==gender].shape[0])
    
plt.bar(genders, counts)
plt.xlabel('genders')
plt.ylabel('frequency')
plt.title('Bar plot of genders')
# Out:
# Text(0.5, 1.0, 'Bar plot of genders')

# %%
years = list(data['year'].unique())
counts = []
for year in years:
    counts.append(data[data['year']==year].shape[0])
    
plt.bar(years, counts)
plt.xlabel('years')
plt.ylabel('frequency')
plt.title('Bar plot of years')
# Out:
# Text(0.5, 1.0, 'Bar plot of years')

# %%
scatter_matrix(data, figsize = (15,15))
plt.show()

# %% [markdown]
# ### Advanced Statistical Analysis:

# %%
# Calculating mean for each attribute in the dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
mean_vector = np.mean(data[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'year']], axis=0)
mean_vector
# Out:
# bill_length_mm         43.921930
# bill_depth_mm          17.151170
# flipper_length_mm     200.915205
# body_mass_g          4201.754386
# year                 2008.029070
# dtype: float64

# %%
numerical_data_centered = data[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'year']] - mean_vector

# covariance using inner product
inner_product = np.dot(numerical_data_centered.T, numerical_data_centered)

cov_matrix_inner = inner_product/(numerical_data_centered.shape[0] - 1)
print("Sample Covariance Matrix using inner product: ")
pd.DataFrame(cov_matrix_inner)
# Out:
# Sample Covariance Matrix using inner product:
#              0           1            2              3          4
# 0    29.633252   -2.519457    50.082029    2590.398957   0.241926
# 1    -2.519457    3.877069   -16.118414    -743.012250  -0.096827
# 2    50.082029  -16.118414   196.578837    9767.130837   1.938332
# 3  2590.398957 -743.012250  9767.130837  639381.041890  27.499872
# 4     0.241926   -0.096827     1.938332      27.499872   0.669706

# %%
# Covariance using outer product
outer_products = [np.outer(numerical_data_centered[:, i], numerical_data_centered[:, j]) for i in range(numerical_data_centered.shape[1]) for j in range(numerical_data_centered.shape[1])]
sum_outer_product = np.sum(outer_products, axis=0)

cov_matrix_outer = sum_outer_products/(numerical_data_centered.shape[0] - 1)

print('Sample covariance matrix using outer product: ')
pd.DataFrame(cov_matrix_outer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[72], line 2
#       1 # Covariance using outer product
# ----> 2 outer_products = [np.outer(numerical_data_centered[:, i], numerical_data_centered[:, j]) for i in range(numerical_data_centered.shape[1]) for j in range(numerical_data_centered.shape[1])]
#       3 sum_outer_product = np.sum(outer_products, axis=0)
#       5 cov_matrix_outer = sum_outer_products/(numerical_data_centered.shape[0] - 1)
#
# Cell In[72], line 2, in <listcomp>(.0)
#       1 # Covariance using outer product
# ----> 2 outer_products = [np.outer(numerical_data_centered[:, i], numerical_data_centered[:, j]) for i in range(numerical_data_centered.shape[1]) for j in range(numerical_data_centered.shape[1])]
#       3 sum_outer_product = np.sum(outer_products, axis=0)
#       5 cov_matrix_outer = sum_outer_products/(numerical_data_centered.shape[0] - 1)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3660, in Index.get_loc(self, key)
#    3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
# -> 3660     self._check_indexing_error(key)
#    3661     raise
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5737, in Index._check_indexing_error(self, key)
#    5733 def _check_indexing_error(self, key):
#    5734     if not is_scalar(key):
#    5735         # if key is not a scalar, directly raise an error (the code below
#    5736         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5737         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), 0)

# %%
length_depth_corr = data[['bill_length_mm', 'bill_depth_mm']].corr()
length_depth_corr
# Out:
#                 bill_length_mm  bill_depth_mm
# bill_length_mm        1.000000      -0.235053
# bill_depth_mm        -0.235053       1.000000

# %%
centered_data = data[['bill_length_mm', 'bill_depth_mm']] - data[['bill_length_mm', 'bill_depth_mm']].mean()

dot_product = np.dot(centered_data['bill_length_mm'], centered_data['bill_depth_mm'])
norm_v1 = np.linalg.norm(centered_data['bill_length_mm'])
norm_v2 = np.linalg.norm(centered_data['bill_depth_mm'])

correlation = dot_product / (norm_v1 * norm_v2)
print('Correlation between bill_length_mm and bill_depth_mm : ', correlation)
# Out:
# Correlation between bill_length_mm and bill_depth_mm :  -0.23505287035553274

# %%
covar_matrix = data[['species', 'island', 'sex']].cov()
covar_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 covar_matrix = data[['species', 'island', 'sex']].cov()
#       2 covar_matrix
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:10210, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   10208 cols = data.columns
#   10209 idx = cols.copy()
# > 10210 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10212 if notna(mat).all():
#   10213     if min_periods is not None and min_periods > len(mat):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Adelie'
